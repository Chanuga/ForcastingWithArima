# %%
import pandas as pd
from pandas import datetime 
import matplotlib.pyplot as plt
# Out:
# C:\Users\Chanuga\AppData\Local\Temp/ipykernel_14136/666295779.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
def parser(x):
    return datetime.strptime(x, '%Y-%m')
sales = pd.read_csv('Test.csv',index_col=0, parse_dates=[0], date_parser=parser )
sales.head()
# Out:
#             Sales
# Month
# 2021-01-01     10
# 2021-02-01   1500
# 2021-03-01     10
# 2021-04-01   2000
# 2021-05-01    150

# %%
# sales.Month[0]

# %%
sales.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(sales)

# %%
sales.diff(periods=1)
# Out:
#              Sales
# Month
# 2021-01-01     NaN
# 2021-02-01  1490.0
# 2021-03-01 -1490.0
# 2021-04-01  1990.0
# 2021-05-01 -1850.0
# 2021-06-01  -140.0
# 2021-07-01    90.0
# 2021-08-01   -99.0

# %%
plot_acf(sales.diff(periods=1))
